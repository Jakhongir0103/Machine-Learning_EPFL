# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# Load test module for sanity check
from test_utils import test

# %% [markdown]
# # Logistic Regression
# ## Classification Using Linear Regression
# Load your data.

# %%
from helpers import sample_data, load_data, standardize

# load data.
height, weight, gender = load_data()

# build sampled x and y.
seed = 1
y = np.expand_dims(gender, axis=1)
X = np.c_[height.reshape(-1), weight.reshape(-1)]
y, X = sample_data(y, X, seed, size_samples=200)
x, mean_x, std_x = standardize(X)

# %% [markdown]
# Use `least_squares` to compute w, and visualize the results.

# %%
from least_squares import least_squares
from plots import visualization


def least_square_classification_demo(y, x):
    """Least square demo

    Args:
        y:  shape=(N, 1)
        x:  shape=(N, 2)
    """
    # classify the data by linear regression
    tx = np.c_[np.ones((y.shape[0], 1)), x]
    w, loss = least_squares(y, tx)
    mean_x = np.mean(x)
    std_x = np.std(x)

    # visualize your classification.
    visualization(y, x, mean_x, std_x, w, "classification_by_least_square")


least_square_classification_demo(y, x)

# %% [markdown]
# #### The `least_square_classification_demo` is expected to show
#
# ![1](./classification_by_least_square.png)

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# Compute your cost by negative log likelihood.

# %%
def sigmoid(t):
    """apply sigmoid function on t.

    Args:
        t: scalar or numpy array

    Returns:
        scalar or numpy array

    >>> sigmoid(np.array([0.1]))
    array([0.52497919])
    >>> sigmoid(np.array([0.1, 0.1]))
    array([0.52497919, 0.52497919])
    """
    sigmoid = np.power(1 + np.exp(-t), -1)

    return sigmoid

test(sigmoid)
# Out:
# ✅ Your `sigmoid` passed 2 tests.

# %%
def calculate_loss(y, tx, w):
    """compute the cost by negative log likelihood.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)

    Returns:
        a non-negative loss

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(4).reshape(2, 2)
    >>> w = np.c_[[2., 3.]]
    >>> round(calculate_loss(y, tx, w), 8)
    1.52429481
    """
    assert y.shape[0] == tx.shape[0]
    assert tx.shape[1] == w.shape[0]

    N = len(y)
    loss = -(y.T @ np.log(sigmoid(tx @ w)) + (1 - y).T @ np.log(1 - sigmoid(tx @ w))) / N
    return loss.item()
test(calculate_loss)
# Out:
# ✅ Your `calculate_loss` passed 4 tests.

# %%
def calculate_gradient(y, tx, w):
    """compute the gradient of loss.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)

    Returns:
        a vector of shape (D, 1)

    >>> np.set_printoptions(8)
    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> calculate_gradient(y, tx, w)
    array([[-0.10370763],
           [ 0.2067104 ],
           [ 0.51712843]])
    """
    N = len(y)
    gradient = (tx.T @ (sigmoid(tx @ w) - y)) / N
    return gradient

test(calculate_gradient)
# Out:
# ✅ Your `calculate_gradient` passed 5 tests.

# %% [markdown]
# ### Using Gradient Descent
# Implement your function to calculate the gradient for logistic regression.

# %%
def learning_by_gradient_descent(y, tx, w, gamma):
    """
    Do one step of gradient descent using logistic regression. Return the loss and the updated w.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)
        gamma: float

    Returns:
        loss: scalar number
        w: shape=(D, 1)

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> gamma = 0.1
    >>> loss, w = learning_by_gradient_descent(y, tx, w, gamma)
    >>> round(loss, 8)
    0.62137268
    >>> w
    array([[0.11037076],
           [0.17932896],
           [0.24828716]])
    """
    gradient = calculate_gradient(y, tx, w)
    loss = calculate_loss(y, tx, w)
    w = w - gamma * gradient

    return loss, w

test(learning_by_gradient_descent)
# Out:
# ✅ Your `learning_by_gradient_descent` passed 7 tests.

# %% [markdown]
# Demo!

# %%
from helpers import de_standardize


def logistic_regression_gradient_descent_demo(y, x):
    # init parameters
    max_iter = 10000
    threshold = 1e-8
    gamma = 0.5
    losses = []

    # build tx
    tx = np.c_[np.ones((y.shape[0], 1)), x]
    w = np.zeros((tx.shape[1], 1))

    # start the logistic regression
    for iter in range(max_iter):
        # get loss and update w.
        loss, w = learning_by_gradient_descent(y, tx, w, gamma)
        # log info
        if iter % 100 == 0:
            print("Current iteration={i}, loss={l}".format(i=iter, l=loss))
        # converge criterion
        losses.append(loss)
        if len(losses) > 1 and np.abs(losses[-1] - losses[-2]) < threshold:
            break
    # visualization
    visualization(
        y,
        x,
        mean_x,
        std_x,
        w,
        "classification_by_logistic_regression_gradient_descent",
        True,
    )
    print("loss={l}".format(l=calculate_loss(y, tx, w)))


logistic_regression_gradient_descent_demo(y, x)
# Out:
# Current iteration=0, loss=0.6931471805599452
# Current iteration=100, loss=0.2572780775822991
# Current iteration=200, loss=0.2354612766230435
# Current iteration=300, loss=0.22402749546644216
# Current iteration=400, loss=0.21743934892145103
# Current iteration=500, loss=0.21337866206030554
# Current iteration=600, loss=0.2107498111157124
# Current iteration=700, loss=0.20898450986240572
# Current iteration=800, loss=0.2077655124329582
# Current iteration=900, loss=0.20690519298954663
# Current iteration=1000, loss=0.2062873819541177
# Current iteration=1100, loss=0.20583744941158436
# Current iteration=1200, loss=0.20550598727687255
# Current iteration=1300, loss=0.20525946348042884
# Current iteration=1400, loss=0.20507464518877044
# Current iteration=1500, loss=0.20493515330970438
# Current iteration=1600, loss=0.20482926953052655
# Current iteration=1700, loss=0.20474850436405456
# Current iteration=1800, loss=0.2046866411426354
# Current iteration=1900, loss=0.2046390853160284
# Current iteration=2000, loss=0.2046024140059617
# Current iteration=2100, loss=0.20457405952827123
# Current iteration=2200, loss=0.20455208411719808
# Current iteration=2300, loss=0.20453501771155266
# Current iteration=2400, loss=0.20452173995435652
# Current iteration=2500, loss=0.20451139357783976
# Current iteration=2600, loss=0.20450332031614318
# Current iteration=2700, loss=0.20449701314932478
# Current iteration=2800, loss=0.20449208049247558
# Current iteration=2900, loss=0.20448821919174937
# Current iteration=3000, loss=0.20448519406015742
# Current iteration=3100, loss=0.20448282230082498
# Current iteration=3200, loss=0.20448096160389256
# Current iteration=3300, loss=0.20447950101893528
# Current iteration=3400, loss=0.20447835393401814
# loss=0.2044782735718383

# %% [markdown]
# #### The `logistic_regression_gradient_descent_demo` is expected to show
#
# ![1](../template/classification_by_logistic_regression_gradient_descent.png)

# %% [markdown]
# Calculate your hessian below

# %%
def calculate_hessian(y, tx, w):
    """return the Hessian of the loss function.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)

    Returns:
        a hessian matrix of shape=(D, D)

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> calculate_hessian(y, tx, w)
    array([[0.28961235, 0.3861498 , 0.48268724],
           [0.3861498 , 0.62182124, 0.85749269],
           [0.48268724, 0.85749269, 1.23229813]])
    """
    N = len(y)
    s = np.diagflat(sigmoid(tx @ w) * (1 - sigmoid(tx @ w)))
    hessian = (tx.T @ s @ tx) / N
    return hessian

test(calculate_hessian)
# Out:
# ✅ Your `calculate_hessian` passed 4 tests.

# %% [markdown]
# Write a function below to return loss, gradient, and hessian.

# %%
def logistic_regression(y, tx, w):
    """return the loss, gradient of the loss, and hessian of the loss.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)

    Returns:
        loss: scalar number
        gradient: shape=(D, 1)
        hessian: shape=(D, D)

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> loss, gradient, hessian = logistic_regression(y, tx, w)
    >>> round(loss, 8)
    0.62137268
    >>> gradient, hessian
    (array([[-0.10370763],
           [ 0.2067104 ],
           [ 0.51712843]]), array([[0.28961235, 0.3861498 , 0.48268724],
           [0.3861498 , 0.62182124, 0.85749269],
           [0.48268724, 0.85749269, 1.23229813]]))
    """
    loss = calculate_loss(y, tx, w)
    gradient = calculate_gradient(y, tx, w)
    hessian = calculate_hessian(y, tx, w)

    return loss, gradient, hessian
test(logistic_regression)
# Out:
# ✅ Your `logistic_regression` passed 6 tests.

# %% [markdown]
# ### Using Newton's method
# Use Newton's method for logistic regression.

# %%
def learning_by_newton_method(y, tx, w, gamma):
    """
    Do one step of Newton's method.
    Return the loss and updated w.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)
        gamma: scalar

    Returns:
        loss: scalar number
        w: shape=(D, 1)

    >>> y = np.c_[[0., 0., 1., 1.]]
    >>> np.random.seed(0)
    >>> tx = np.random.rand(4, 3)
    >>> w = np.array([[0.1], [0.5], [0.5]])
    >>> gamma = 0.1
    >>> loss, w = learning_by_newton_method(y, tx, w, gamma)
    >>> round(loss, 8)
    0.71692036
    >>> w
    array([[-1.31876014],
           [ 1.0590277 ],
           [ 0.80091466]])
    """
    loss, gradient, hessian = logistic_regression(y, tx, w)
    w = w - gamma * np.linalg.solve(hessian, np.identity(len(hessian))) @ gradient
    
    return loss, w


test(learning_by_newton_method)
# Out:
# ✅ Your `learning_by_newton_method` passed 8 tests.

# %% [markdown]
# demo

# %%
def logistic_regression_newton_method_demo(y, x):
    # init parameters
    max_iter = 100
    threshold = 1e-8
    lambda_ = 0.1
    gamma = 1.0
    losses = []

    # build tx
    tx = np.c_[np.ones((y.shape[0], 1)), x]
    w = np.zeros((tx.shape[1], 1))

    # start the logistic regression
    for iter in range(max_iter):
        # get loss and update w.
        loss, w = learning_by_newton_method(y, tx, w, gamma)
        # log info
        if iter % 1 == 0:
            print("Current iteration={i}, the loss={l}".format(i=iter, l=loss))

        # converge criterion
        losses.append(loss)
        if len(losses) > 1 and np.abs(losses[-1] - losses[-2]) < threshold:
            break
    # visualization
    visualization(
        y,
        x,
        mean_x,
        std_x,
        w,
        "classification_by_logistic_regression_newton_method",
        True,
    )
    print("loss={l}".format(l=calculate_loss(y, tx, w)))


logistic_regression_newton_method_demo(y, x)
# Out:
# Current iteration=0, the loss=0.6931471805599452
# Current iteration=1, the loss=0.3170577686954798
# Current iteration=2, the loss=0.23652293099675328
# Current iteration=3, the loss=0.20998733711242248
# Current iteration=4, the loss=0.2047819931861897
# Current iteration=5, the loss=0.20447559968244786
# Current iteration=6, the loss=0.2044741280881354
# Current iteration=7, the loss=0.20447412804945292
# loss=0.20447412804945295

# %% [markdown]
# #### The `logistic_regression_newton_method_demo` is expected to show
#
# ![1](../template/classification_by_logistic_regression_newton_method.png)

# %% [markdown]
# ### Using penalized logistic regression
# Fill in the function below.

# %%
def penalized_logistic_regression(y, tx, w, lambda_):
    """return the loss and gradient.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)
        lambda_: scalar

    Returns:
        loss: scalar number
        gradient: shape=(D, 1)

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> lambda_ = 0.1
    >>> loss, gradient = penalized_logistic_regression(y, tx, w, lambda_)
    >>> round(loss, 8)
    0.63537268
    >>> gradient
    array([[-0.08370763],
           [ 0.2467104 ],
           [ 0.57712843]])
    """

    N = len(y)
    loss = calculate_loss(y, tx, w) + lambda_ * np.power(np.linalg.norm(w),2)
    gradient = calculate_gradient(y, tx, w) + 2 * lambda_ * w

    return loss.item(), gradient

test(penalized_logistic_regression)
# Out:
# ✅ Your `penalized_logistic_regression` passed 7 tests.

# %%
def learning_by_penalized_gradient(y, tx, w, gamma, lambda_):
    """
    Do one step of gradient descent, using the penalized logistic regression.
    Return the loss and updated w.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)
        gamma: scalar
        lambda_: scalar

    Returns:
        loss: scalar number
        w: shape=(D, 1)

    >>> np.set_printoptions(8)
    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> lambda_ = 0.1
    >>> gamma = 0.1
    >>> loss, w = learning_by_penalized_gradient(y, tx, w, gamma, lambda_)
    >>> round(loss, 8)
    0.63537268
    >>> w
    array([[0.10837076],
           [0.17532896],
           [0.24228716]])
    """
    loss, gradient = penalized_logistic_regression(y, tx, w, lambda_)
    w = w - gamma * gradient
    
    return loss, w


test(learning_by_penalized_gradient)
# Out:
# ✅ Your `learning_by_penalized_gradient` passed 9 tests.

# %%
def logistic_regression_penalized_gradient_descent_demo(y, x):
    # init parameters
    max_iter = 10000
    gamma = 0.5
    lambda_ = 0.0005
    threshold = 1e-8
    losses = []

    # build tx
    tx = np.c_[np.ones((y.shape[0], 1)), x]
    w = np.zeros((tx.shape[1], 1))

    # start the logistic regression
    for iter in range(max_iter):
        # get loss and update w.
        loss, w = learning_by_penalized_gradient(y, tx, w, gamma, lambda_)
        # log info
        # if iter % 100 == 0:
        #     print("Current iteration={i}, loss={l}, lambda={la}".format(i=iter, l=loss, la=lambda_))
        # converge criterion
        losses.append(loss)
        if len(losses) > 1 and np.abs(losses[-1] - losses[-2]) < threshold:
            break
    # visualization
    visualization(
        y,
        x,
        mean_x,
        std_x,
        w,
        "classification_by_logistic_regression_penalized_gradient_descent",
        True,
    )
    print("loss={l}".format(l=calculate_loss(y, tx, w)))


logistic_regression_penalized_gradient_descent_demo(y, x)
# Out:
# loss=0.20918543764035633

# %% [markdown]
# #### The `logistic_regression_penalized_gradient_descent_demo` is expected to show
#
# ![1](../template/classification_by_logistic_regression_penalized_gradient_descent.png)

# %%
def logistic_regression_penalized_gradient_descent_demo(y, x):
    # init parameters
    max_iter = 10000
    gamma = 0.5
    lambdas = np.logspace(-10,0,10)
    threshold = 1e-8
    losses = []

    # build tx
    tx = np.c_[np.ones((y.shape[0], 1)), x]
    w = np.zeros((tx.shape[1], 1))

    # start the logistic regression
    for lambda_ in lambdas:
        for iter in range(max_iter):
            # get loss and update w.
            loss, w = learning_by_penalized_gradient(y, tx, w, gamma, lambda_)
            # log info
            # if iter % 100 == 0:
            #     print("Current iteration={i}, loss={l}, lambda={la}".format(i=iter, l=loss, la=lambda_))
            # converge criterion
            losses.append(loss)
            if len(losses) > 1 and np.abs(losses[-1] - losses[-2]) < threshold:
                break
        # visualization
        visualization(
            y,
            x,
            mean_x,
            std_x,
            w,
            "classification_by_logistic_regression_penalized_gradient_descent",
            True,
        )
        print("loss={l}, lambda={la}".format(l=calculate_loss(y, tx, w),la=lambda_))

logistic_regression_penalized_gradient_descent_demo(y, x)
# Out:
# loss=0.20447827365008714, lambda=1e-10
# loss=0.2044782538028371, lambda=1.2915496650148826e-09
# loss=0.20447823408211774, lambda=1.6681005372000592e-08
# loss=0.20447821485637008, lambda=2.1544346900318867e-07
# loss=0.20447820088188443, lambda=2.782559402207126e-06
# loss=0.20450227427954487, lambda=3.5938136638046256e-05
# loss=0.20842512095272653, lambda=0.0004641588833612782
# loss=0.25524423872852, lambda=0.005994842503189421
# loss=0.37152401565353393, lambda=0.07742636826811278
# loss=0.5918558934138892, lambda=1.0
